# %%
# import statistics Library
import statistics
# import seaborn
import seaborn as sns

# %%
# Sample data
data = [12, 15, 10, 15, 17, 18, 10, 15, 15, 20, 22, 25, 30]

# %%
sns.kdeplot(data , fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# Mean (Average)
mean = statistics.mean(data)
print("Mean (Average):", mean)
# Out:
# Mean (Average): 17.23076923076923

# %%
# Median (Middle Value)
median = statistics.median(data)
print("Median (Middle Value):", median)
# Out:
# Median (Middle Value): 15

# %%
# Mode (Most Frequent Value)
try:
    mode = statistics.mode(data)
    print("Mode (Most Frequent Value):", mode)
except statistics.StatisticsError:
    print("Mode (Most Frequent Value): No unique mode")
# Out:
# Mode (Most Frequent Value): 15

# %%
# Additional Statistics
variance = statistics.variance(data)
print("Variance:", variance)

std_deviation = statistics.stdev(data)
print("Standard Deviation:", std_deviation)
# Out:
# Variance: 33.85897435897436
# Standard Deviation: 5.818846480100189
