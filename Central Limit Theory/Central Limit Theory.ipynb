# %% [markdown]
# # Import Libraries

# %%
import numpy.random as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Generate Data

# %%
population_size = 1000000
population = np.rand(1000000)

# %% [markdown]
# We define the ‘sample_size’ to be 1. Later we will experiment with different values of ‘sample_size’.

# %%
number_of_samples = 10000
sample_means = np.rand(number_of_samples)
sample_size = 1

# %% [markdown]
# We run a ‘for loop’ 10000 times. Each time ‘c’ takes up integer values between 1 and population_size and size of ‘c’ is same as ‘sample_size’. The sample is drawn from population and its mean is stored in ‘sample_mean’.

# %%
c = np.rand(number_of_samples)
for i in range(0,number_of_samples):
 c = np.randint(1,population_size,sample_size)
 sample_means[i] = population[c].mean()

# %% [markdown]
# **Sample size =1**

# %%
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_means,bins=int(180/5),hist = True,kde = False)
plt.title("Histogram of Sample mean",fontsize=20)
plt.xlabel("Sample mean",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_means,hist = False,kde = True)
plt.title("Density of Sample mean",fontsize=20)
plt.xlabel("Sample mean",fontsize=20)
plt.ylabel("Density",fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
# Out:
# <ipython-input-8-ab4ebe1f8009>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_means,bins=int(180/5),hist = True,kde = False)
# <ipython-input-8-ab4ebe1f8009>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_means,hist = False,kde = True)

# %%
number_of_samples = 10000
sample_means = np.rand(number_of_samples)
sample_size = 5

# %%
c = np.rand(number_of_samples)
for i in range(0,number_of_samples):
 c = np.randint(1,population_size,sample_size)
 sample_means[i] = population[c].mean()

# %%
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_means,bins=int(180/5),hist = True,kde = False)
plt.title("Histogram of Sample mean",fontsize=20)
plt.xlabel("Sample mean",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_means,hist = False,kde = True)
plt.title("Density of Sample mean",fontsize=20)
plt.xlabel("Sample mean",fontsize=20)
plt.ylabel("Density",fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
# Out:
# <ipython-input-22-ab4ebe1f8009>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_means,bins=int(180/5),hist = True,kde = False)
# <ipython-input-22-ab4ebe1f8009>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_means,hist = False,kde = True)

# %%
sample_size = 30

# %%
c = np.rand(number_of_samples)
for i in range(0,number_of_samples):
 c = np.randint(1,population_size,sample_size)
 sample_means[i] = population[c].mean()

# %%
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_means,bins=int(180/5),hist = True,kde = False)
plt.title("Histogram of Sample mean",fontsize=20)
plt.xlabel("Sample mean",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_means,hist = False,kde = True)
plt.title("Density of Sample mean",fontsize=20)
plt.xlabel("Sample mean",fontsize=20)
plt.ylabel("Density",fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
# Out:
# <ipython-input-25-ab4ebe1f8009>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_means,bins=int(180/5),hist = True,kde = False)
# <ipython-input-25-ab4ebe1f8009>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_means,hist = False,kde = True)

# %%
sample_size = 100

# %%
c = np.rand(number_of_samples)
for i in range(0,number_of_samples):
 c = np.randint(1,population_size,sample_size)
 sample_means[i] = population[c].mean()

# %%
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_means,bins=int(180/5),hist = True,kde = False)
plt.title("Histogram of Sample mean",fontsize=20)
plt.xlabel("Sample mean",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_means,hist = False,kde = True)
plt.title("Density of Sample mean",fontsize=20)
plt.xlabel("Sample mean",fontsize=20)
plt.ylabel("Density",fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
# Out:
# <ipython-input-27-ab4ebe1f8009>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_means,bins=int(180/5),hist = True,kde = False)
# <ipython-input-27-ab4ebe1f8009>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_means,hist = False,kde = True)
